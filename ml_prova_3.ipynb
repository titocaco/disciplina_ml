# %% [markdown]
# # Exercícios para entrega (Prova)

# %% [markdown]
# ## Questão 3

# %% [markdown]
# $p(x|\omega_{1}) \backsim \mathcal{N}(7, 1)$
#
# $p(x|\omega_{2}) \backsim \mathcal{N}(7, 4)$
#
# $P(\omega_{1}) = P(\omega_{2}) = \frac{1}{2}$

# %%
# Importação de módulos
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

np.random.seed(100)

# %%
# Delimitação de dimensões para as figuras
X_MIN = -6
X_MAX = 22
N_PONTOS = 1000

# %% [markdown]
# $p(x | \omega_{i})$

# %%
plt.figure(figsize=(10, 8))

# Para i=1
MEDIA = 7
DESVIO_PADRAO = 1

x = np.linspace(X_MIN, X_MAX, N_PONTOS)
y = norm.pdf(x, MEDIA, DESVIO_PADRAO)

plt.plot(x, y, color='C0')
plt.fill_between(x, y, color='C0', alpha=0.5, label=r'$\omega_1$')

# Para i=2
MEDIA = 7
DESVIO_PADRAO = 4

x = np.linspace(X_MIN, X_MAX, N_PONTOS)
y = norm.pdf(x, MEDIA, DESVIO_PADRAO)

plt.plot(x, y, color='C2')
plt.fill_between(x, y, color='C2', alpha=0.5, label=r'$\omega_2$')

plt.legend(fontsize=18)
plt.grid(True, linestyle='--', linewidth=1.0, alpha=0.5)

# Ajustes extras do plot
plt.xlim(X_MIN, X_MAX)
plt.ylim(0.0, 0.5)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel(r'$x$', fontsize=24)
plt.ylabel(r'$p(x | \omega_i)$', fontsize=24)

# Salvamento da figura em PDF
plt.savefig('ml_prova_03_a1.pdf',
            format='pdf',
            dpi=300,
            transparent=True,
            bbox_inches='tight')

# Exibicação 'limpa' da figura
plt.show()

# %% [markdown]
# $p(x | \omega_{i})\cdot P(\omega_{i})$

# %%
plt.figure(figsize=(10, 8))

# Para i=1
MEDIA = 7
DESVIO_PADRAO = 1

x = np.linspace(X_MIN, X_MAX, N_PONTOS)
y = 0.5 * norm.pdf(x, MEDIA, DESVIO_PADRAO)

plt.plot(x, y, color='C0')
plt.fill_between(x, y, color='C0', alpha=0.5, label=r'$\omega_1$')

# Para i=2
MEDIA = 7
DESVIO_PADRAO = 4

x = np.linspace(X_MIN, X_MAX, N_PONTOS)
y = 0.5 * norm.pdf(x, MEDIA, DESVIO_PADRAO)

plt.plot(x, y, color='C2')
plt.fill_between(x, y, color='C2', alpha=0.5, label=r'$\omega_2$')

plt.legend(fontsize=18)
plt.grid(True, linestyle='--', linewidth=1.0, alpha=0.5)

# # Plot do limiar de decisão
plt.axvline(x=5.64, linestyle='--', color='red')
plt.annotate('Limiares de Decisão', 
             xy=(5.64, 0.3), 
             xytext=(11.1, 0.35), 
             arrowprops=dict(facecolor='red', 
                             shrink=0.05, 
                             width=1.5, 
                             edgecolor='red'), 
             color='red', 
             fontsize=18)

plt.axvline(x=8.36, linestyle='--', color='red')
plt.annotate('', 
             xy=(8.36, 0.3), 
             xytext=(11.1, 0.349), 
             arrowprops=dict(facecolor='red', 
                             shrink=0.05, 
                             width=1.5, 
                             edgecolor='red'), 
             color='red', 
             fontsize=18)

plt.annotate('$\{x=5.64\}$', xy=(13.0, 0.32), fontsize=18, color='red')
plt.annotate('$\{x=8.36\}$', xy=(13.0, 0.29), fontsize=18, color='red')

plt.axvspan(X_MIN, 5.64, alpha=0.2, color='C2')
plt.axvspan(5.64, 8.36, alpha=0.2, color='C0')
plt.axvspan(8.36, X_MAX, alpha=0.2, color='C2')

# Ajustes extras do plot
plt.xlim(X_MIN, X_MAX)
plt.ylim(0.0, 0.5)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel(r'$x$', fontsize=24)
plt.ylabel(r'$p(x | \omega_i)\cdot P(\omega_i)$', fontsize=24)

# Salvamento da figura em PDF
plt.savefig('ml_prova_03_a2.pdf',
            format='pdf',
            dpi=300,
            transparent=True,
            bbox_inches='tight')

# Exibicação 'limpa' da figura
plt.show()

# %% [markdown]
# ### Simulando a classificação de N=1000 novas amostras

# %%
# Geração de um conjunto de 500 amostras da classe omega_1 e 500 amostras da classe omega_2
amostras_omega1 = np.random.normal(7, 1, int(N_PONTOS/2))
amostras_omega2 = np.random.normal(7, 4, int(N_PONTOS/2))

# %%
# Plot dos dados
plt.figure(figsize=(10, 8))

_, _, _ = plt.hist(amostras_omega1, 30, density=True, color='C0', alpha=0.5, label=r'$\omega_1$')
_, _, _ = plt.hist(amostras_omega2, 30, density=True, color='C2', alpha=0.5, label=r'$\omega_2$')

plt.legend(fontsize=18)
plt.grid(True, linestyle='--', linewidth=1.0, alpha=0.5)

# # Plot do limiar de decisão
plt.axvline(x=5.64, linestyle='--', color='red')
plt.annotate('Limiares de Decisão', 
             xy=(5.64, 0.3), 
             xytext=(11.1, 0.35), 
             arrowprops=dict(facecolor='red', 
                             shrink=0.05, 
                             width=1.5, 
                             edgecolor='red'), 
             color='red', 
             fontsize=18)

plt.axvline(x=8.36, linestyle='--', color='red')
plt.annotate('', 
             xy=(8.36, 0.3), 
             xytext=(11.1, 0.349), 
             arrowprops=dict(facecolor='red', 
                             shrink=0.05, 
                             width=1.5, 
                             edgecolor='red'), 
             color='red', 
             fontsize=18)

plt.annotate('$\{x=5.64\}$', xy=(13.0, 0.32), fontsize=18, color='red')
plt.annotate('$\{x=8.36\}$', xy=(13.0, 0.29), fontsize=18, color='red')

plt.axvspan(X_MIN, 5.64, alpha=0.2, color='C2')
plt.axvspan(5.64, 8.36, alpha=0.2, color='C0')
plt.axvspan(8.36, X_MAX, alpha=0.2, color='C2')

# Ajustes extras do plot
plt.xlim(X_MIN, X_MAX)
plt.ylim(0.0, 0.5)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel(r'$x$', fontsize=24)
plt.ylabel(r'$p(x | \omega_i)\cdot P(\omega_i)$', fontsize=24)

# Salvamento da figura em PDF
plt.savefig('ml_prova_03_simulacao_1000_amostras.pdf',
            format='pdf',
            dpi=300,
            transparent=True,
            bbox_inches='tight')

# Exibicação 'limpa' da figura
plt.show()

# %%
# Função que classifica uma amostra segundo um dado limiar
def classificar(amostra, limiar_menor, limiar_maior):
    if amostra > limiar_menor and amostra < limiar_maior:
        return 1
    else:
        return 2

# %%
# Função que classifica um conjunto de amostras de acordo com um dado limiar
def classificar_conjunto(amostras, limiar_menor, limiar_maior):
    return np.array([classificar(amostra, limiar_menor, limiar_maior) for amostra in amostras])

# %%
# Função que calcula a quantidade de erros de classificação e a taxa de erro de classificação
def erros(classes_preditas, classe_correta):
    n_erros = 0
    for amostra in classes_preditas:
        if amostra != classe_correta:
            n_erros += 1
    taxa_de_erros = n_erros/len(classes_preditas)
    return n_erros, taxa_de_erros

# %%
# Classificação de uma amostra de acordo com um dado limiar
pred_omega1 = classificar_conjunto(amostras_omega1, limiar_menor=5.64, limiar_maior=8.36)
pred_omega2 = classificar_conjunto(amostras_omega2, limiar_menor=5.64, limiar_maior=8.36)

# %%
# Cálculo das quantidades de erros de classificação e da taxas de erro de classificação para cada classe
erros_omega1 = erros(classes_preditas=pred_omega1, classe_correta=1)
print('Classe 1\n--------------------------------')
print('Erros de Classificação: \t%d de %d' % (erros_omega1[0], int(N_PONTOS/2)))
print('Taxa de Erro de Classificação: \t%.4f' % erros_omega1[1])

erros_omega2 = erros(classes_preditas=pred_omega2, classe_correta=2)
print('\n\nClasse 2\n--------------------------------')
print('Erros de Classificação: \t%d de %d' % (erros_omega2[0], int(N_PONTOS/2)))
print('Taxa de Erro de Classificação: \t%.4f' % erros_omega2[1])
# Out:
# Classe 1
# --------------------------------
# Erros de Classificação: 	90 de 500
# Taxa de Erro de Classificação: 	0.1800
#
#
# Classe 2
# --------------------------------
# Erros de Classificação: 	132 de 500
# Taxa de Erro de Classificação: 	0.2640

# %%
# Cálculo da quantidade geral de erros de classificação e da taxa de erro de classificação
erros_gerais = (erros_omega1[0] + erros_omega2[0], 0.5 * (erros_omega1[1] + erros_omega2[1]))
print('Avaliação Geral do Classificador\n--------------------------------')
print('Erros de Classificação: \t%d de %d' % (erros_gerais[0], N_PONTOS))
print('Taxa de Erro de Classificação: \t%.4f' % erros_gerais[1])
# Out:
# Avaliação Geral do Classificador
# --------------------------------
# Erros de Classificação: 	222 de 1000
# Taxa de Erro de Classificação: 	0.2220
